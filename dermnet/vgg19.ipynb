# %%
import numpy as np
import matplotlib.pyplot as plt
import sys, re
import caffe

sys.path.insert(0, "/home/samskruthi/caffe/python")
plt.rcParams['figure.figsize'] = (10, 10)
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
transformer.set_mean('data', np.load("/home/samskruthi/caffe/python/caffe/imagenet/ilsvrc_2012_mean.npy").mean(1).mean(1))
caffe.set_mode_cpu()
net = caffe.Net("/home/samskruthi/caffe/models/dermnet/vgg19_train_val.prototxt",
                "/home/samskruthi/caffe/models/dermnet/vgg19_iter_200.caffemodel",caffe.TEST)

transformer = caffe.io.Transformer({'data': net.blobs['data'].data.shape})
transformer.set_transpose('data', (2, 0, 1))

transformer.set_raw_scale('data', 255)

net.blobs['data'].reshape(1, 3, 224, 224)


with open("/home/samskruthi/caffe/data/dermnet/test.txt") as testfile:
    test_images = [line.strip().split(' ', 1) for line in testfile] #take test data into test_images

classes = []
regex = re.compile("(^\d+\. .+)$")
with open("/home/samskruthi/caffe/data/dermnet/image_dictionary.txt") as mapfile:
    for line in mapfile:
	match = regex.match(line.strip()) #match with the expression 
	if match:
	    classes.append(match.group(1)) #if matched add to classes

top1_acc = 0
top5_acc = 0
top1 = False
top5 = False
n = 0

for test_image in test_images:
    net.blobs['data'].data[...] = transformer.preprocess('data',caffe.io.load_image(test_image[0])) 
    out = net.forward()
    print("\nImage: %s." % (test_image[0]))
    print("Actual class: %s." % (test_image[1]))
    print("Predicted class: {}.".format(out['prob'][0].argmax())) 
    probabilities = zip(classes, out['prob'][0].tolist())
    probabilities.sort(key=lambda x: x[1])
    for p in probabilities[::-1][:5]:
        if test_image[1] == p[0].split(' ', 1)[0][:-1]:
	        top5_acc += 1
	        top5 = True
    if int(test_image[1]) == out['prob'][0].argmax():
	    top1_acc += 1
	    top1 = True
    
    print("Actual class is equal to Predicted class: %s " % (str(top1)))
    print("Actual class is in top-5 predictions: %s " %(str(top5)))
    print ("The top-5 predicted classes are :")
    for p in probabilities[::-1][:5]:
        print("%s " %(p[0]))
    top1 = False
    top5 = False
    n += 1
    print("The Top-1 accuracy is  : %f" % (float(top1_acc) / n))
    print("The Top-5 accuracy is : %f" % (float(top5_acc) / n))
# Out:
# Image: /home/samskruthi/caffe/data/dermnet/images/psoriasis-scalp-18.jpg.
# Actual class: 14.
# Predicted class: 14.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 16. Seborrheic Keratoses and other Benign Tumors
# 18. Tinea, Candidiasis, and other Fungal Infections
# 8. Herpes, HPV and other STDs Photos
# The Top-1 accuracy is  : 1.000000
# The Top-5 accuracy is : 1.000000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/distal-subungual-onychomycosis-63.jpg.
# Actual class: 12.
# Predicted class: 12.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 12. Nail Fungus and other Nail Disease
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 18. Tinea, Candidiasis, and other Fungal Infections
# 5. Eczema Photos
# 21. Vasculitis Photos
# The Top-1 accuracy is  : 1.000000
# The Top-5 accuracy is : 1.000000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/reiter-syndrome-1.jpg.
# Actual class: 14.
# Predicted class: 18.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 18. Tinea, Candidiasis, and other Fungal Infections
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 22. Warts (Molluscum) and other Viral Infections
# 8. Herpes, HPV and other STDs Photos
# 5. Eczema Photos
# The Top-1 accuracy is  : 0.666667
# The Top-5 accuracy is : 1.000000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/tinea-hand-dorsum-12.jpg.
# Actual class: 18.
# Predicted class: 14.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 5. Eczema Photos
# 18. Tinea, Candidiasis, and other Fungal Infections
# 21. Vasculitis Photos
# 22. Warts (Molluscum) and other Viral Infections
# The Top-1 accuracy is  : 0.500000
# The Top-5 accuracy is : 1.000000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/epidermal-cyst-83.jpg.
# Actual class: 16.
# Predicted class: 16.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 16. Seborrheic Keratoses and other Benign Tumors
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 11. Melanoma (Skin Cancer), Nevi, and Moles
# 22. Warts (Molluscum) and other Viral Infections
# 20. Vascular Tumors
# The Top-1 accuracy is  : 0.600000
# The Top-5 accuracy is : 1.000000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/tinea-foot-webs-28.jpg.
# Actual class: 18.
# Predicted class: 12.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 12. Nail Fungus and other Nail Disease
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 5. Eczema Photos
# 18. Tinea, Candidiasis, and other Fungal Infections
# 22. Warts (Molluscum) and other Viral Infections
# The Top-1 accuracy is  : 0.500000
# The Top-5 accuracy is : 1.000000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/psoriasis-105.jpg.
# Actual class: 12.
# Predicted class: 12.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 12. Nail Fungus and other Nail Disease
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 5. Eczema Photos
# 20. Vascular Tumors
# 16. Seborrheic Keratoses and other Benign Tumors
# The Top-1 accuracy is  : 0.571429
# The Top-5 accuracy is : 1.000000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/xanthomas-15.jpg.
# Actual class: 17.
# Predicted class: 16.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: False
# The top-5 predicted classes are :
# 16. Seborrheic Keratoses and other Benign Tumors
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 18. Tinea, Candidiasis, and other Fungal Infections
# 11. Melanoma (Skin Cancer), Nevi, and Moles
# The Top-1 accuracy is  : 0.500000
# The Top-5 accuracy is : 0.875000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/sebaceous-hyperplasia-79.jpg.
# Actual class: 16.
# Predicted class: 16.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 16. Seborrheic Keratoses and other Benign Tumors
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 22. Warts (Molluscum) and other Viral Infections
# 11. Melanoma (Skin Cancer), Nevi, and Moles
# The Top-1 accuracy is  : 0.555556
# The Top-5 accuracy is : 0.888889
#
# Image: /home/samskruthi/caffe/data/dermnet/images/polymorphous-light-eruption-38.jpg.
# Actual class: 9.
# Predicted class: 22.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: False
# The top-5 predicted classes are :
# 22. Warts (Molluscum) and other Viral Infections
# 18. Tinea, Candidiasis, and other Fungal Infections
# 6. Exanthems and Drug Eruptions
# 21. Vasculitis Photos
# 14. Psoriasis pictures, Lichen Planus and related diseases
# The Top-1 accuracy is  : 0.500000
# The Top-5 accuracy is : 0.800000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/psoriasis-164.jpg.
# Actual class: 12.
# Predicted class: 12.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 12. Nail Fungus and other Nail Disease
# 5. Eczema Photos
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 20. Vascular Tumors
# 16. Seborrheic Keratoses and other Benign Tumors
# The Top-1 accuracy is  : 0.545455
# The Top-5 accuracy is : 0.818182
#
# Image: /home/samskruthi/caffe/data/dermnet/images/malignant-melanoma-20.jpg.
# Actual class: 11.
# Predicted class: 16.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 16. Seborrheic Keratoses and other Benign Tumors
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 11. Melanoma (Skin Cancer), Nevi, and Moles
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 22. Warts (Molluscum) and other Viral Infections
# The Top-1 accuracy is  : 0.500000
# The Top-5 accuracy is : 0.833333
#
# Image: /home/samskruthi/caffe/data/dermnet/images/atypical-nevi-dermoscopy-80.jpg.
# Actual class: 11.
# Predicted class: 16.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 16. Seborrheic Keratoses and other Benign Tumors
# 22. Warts (Molluscum) and other Viral Infections
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 11. Melanoma (Skin Cancer), Nevi, and Moles
# 14. Psoriasis pictures, Lichen Planus and related diseases
# The Top-1 accuracy is  : 0.461538
# The Top-5 accuracy is : 0.846154
#
# Image: /home/samskruthi/caffe/data/dermnet/images/seborrheic-keratoses-smooth-110.jpg.
# Actual class: 16.
# Predicted class: 16.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 16. Seborrheic Keratoses and other Benign Tumors
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 22. Warts (Molluscum) and other Viral Infections
# 11. Melanoma (Skin Cancer), Nevi, and Moles
# The Top-1 accuracy is  : 0.500000
# The Top-5 accuracy is : 0.857143
#
# Image: /home/samskruthi/caffe/data/dermnet/images/lichen-planus-287.jpg.
# Actual class: 14.
# Predicted class: 14.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 16. Seborrheic Keratoses and other Benign Tumors
# 18. Tinea, Candidiasis, and other Fungal Infections
# 5. Eczema Photos
# The Top-1 accuracy is  : 0.533333
# The Top-5 accuracy is : 0.866667
#
# Image: /home/samskruthi/caffe/data/dermnet/images/candidiasis-large-skin-folds-40.jpg.
# Actual class: 18.
# Predicted class: 14.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 18. Tinea, Candidiasis, and other Fungal Infections
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 16. Seborrheic Keratoses and other Benign Tumors
# 8. Herpes, HPV and other STDs Photos
# The Top-1 accuracy is  : 0.500000
# The Top-5 accuracy is : 0.875000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/genital-warts-126.jpg.
# Actual class: 8.
# Predicted class: 1.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: False
# The top-5 predicted classes are :
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 16. Seborrheic Keratoses and other Benign Tumors
# 5. Eczema Photos
# 18. Tinea, Candidiasis, and other Fungal Infections
# The Top-1 accuracy is  : 0.470588
# The Top-5 accuracy is : 0.823529
#
# Image: /home/samskruthi/caffe/data/dermnet/images/lichen-simplex-chronicus-70.jpg.
# Actual class: 5.
# Predicted class: 5.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 5. Eczema Photos
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 18. Tinea, Candidiasis, and other Fungal Infections
# 17. Systemic Disease
# 12. Nail Fungus and other Nail Disease
# The Top-1 accuracy is  : 0.500000
# The Top-5 accuracy is : 0.833333
#
# Image: /home/samskruthi/caffe/data/dermnet/images/median-nail-dystrophy-5.jpg.
# Actual class: 12.
# Predicted class: 12.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 12. Nail Fungus and other Nail Disease
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 5. Eczema Photos
# 20. Vascular Tumors
# 16. Seborrheic Keratoses and other Benign Tumors
# The Top-1 accuracy is  : 0.526316
# The Top-5 accuracy is : 0.842105
#
# Image: /home/samskruthi/caffe/data/dermnet/images/morphea-105.jpg.
# Actual class: 10.
# Predicted class: 22.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: False
# The top-5 predicted classes are :
# 22. Warts (Molluscum) and other Viral Infections
# 18. Tinea, Candidiasis, and other Fungal Infections
# 0. Acne and Rosacea
# 6. Exanthems and Drug Eruptions
# 14. Psoriasis pictures, Lichen Planus and related diseases
# The Top-1 accuracy is  : 0.500000
# The Top-5 accuracy is : 0.800000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/acne-cystic-118.jpg.
# Actual class: 0.
# Predicted class: 18.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 18. Tinea, Candidiasis, and other Fungal Infections
# 22. Warts (Molluscum) and other Viral Infections
# 0. Acne and Rosacea
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 16. Seborrheic Keratoses and other Benign Tumors
# The Top-1 accuracy is  : 0.476190
# The Top-5 accuracy is : 0.809524
#
# Image: /home/samskruthi/caffe/data/dermnet/images/warts-common-29.jpg.
# Actual class: 22.
# Predicted class: 14.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: False
# The top-5 predicted classes are :
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 16. Seborrheic Keratoses and other Benign Tumors
# 18. Tinea, Candidiasis, and other Fungal Infections
# 5. Eczema Photos
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# The Top-1 accuracy is  : 0.454545
# The Top-5 accuracy is : 0.772727
#
# Image: /home/samskruthi/caffe/data/dermnet/images/05atopic0313061.jpg.
# Actual class: 2.
# Predicted class: 5.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: False
# The top-5 predicted classes are :
# 5. Eczema Photos
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 18. Tinea, Candidiasis, and other Fungal Infections
# 21. Vasculitis Photos
# 22. Warts (Molluscum) and other Viral Infections
# The Top-1 accuracy is  : 0.434783
# The Top-5 accuracy is : 0.739130
#
# Image: /home/samskruthi/caffe/data/dermnet/images/seborrheic-keratosis-irritated-166.jpg.
# Actual class: 16.
# Predicted class: 16.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 16. Seborrheic Keratoses and other Benign Tumors
# 1. Actinic Keratosis, Basal Cell Carcinoma and other Malignant Lesions
# 11. Melanoma (Skin Cancer), Nevi, and Moles
# 22. Warts (Molluscum) and other Viral Infections
# 20. Vascular Tumors
# The Top-1 accuracy is  : 0.458333
# The Top-5 accuracy is : 0.750000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/reiter-syndrome-15.jpg.
# Actual class: 14.
# Predicted class: 18.
# Actual class is equal to Predicted class: False
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 18. Tinea, Candidiasis, and other Fungal Infections
# 22. Warts (Molluscum) and other Viral Infections
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 6. Exanthems and Drug Eruptions
# 5. Eczema Photos
# The Top-1 accuracy is  : 0.440000
# The Top-5 accuracy is : 0.760000
#
# Image: /home/samskruthi/caffe/data/dermnet/images/ridging-beading-23.jpg.
# Actual class: 12.
# Predicted class: 12.
# Actual class is equal to Predicted class: True
# Actual class is in top-5 predictions: True
# The top-5 predicted classes are :
# 12. Nail Fungus and other Nail Disease
# 14. Psoriasis pictures, Lichen Planus and related diseases
# 18. Tinea, Candidiasis, and other Fungal Infections
# 20. Vascular Tumors
# 5. Eczema Photos
# The Top-1 accuracy is  : 0.461538
# The Top-5 accuracy is : 0.769231
#
# Image: /home/samskruthi/caffe/data/dermnet/images/habit-tic-deformity-10.jpg.
